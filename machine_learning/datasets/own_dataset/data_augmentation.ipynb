# %%
import os
import subprocess
import cv2
from collections import defaultdict

# Directories
base_path = "/home/haggenmueller/asl_detection/machine_learning/datasets"
raw_videos_path = f"{base_path}/wlasl/raw_videos"
shortened_videos_path = f"{base_path}/own_dataset/shortened_videos"
augmented_videos_path = f"{base_path}/own_dataset/videos_augmented"
os.makedirs(augmented_videos_path, exist_ok=True)

# Augmentations
augmentations = {
    "flip": "-vf hflip",  # Horizontal flip
    "bright": "-vf eq=brightness=0.2",  # Increased brightness
    "contrast": "-vf eq=contrast=1.5",  # Increased contrast
    "speedup": "-vf setpts=0.75*PTS",  # 25% speed increase
    "slowdown": "-filter:v fps=20",  # Slow down
    "noise": "-vf noise=c0s=5:allf=t"  # Add noise
}

# Count videos per label
label_counts = defaultdict(int)
video_sources = {}

def process_videos(folder):
    for video_file in os.listdir(folder):
        if video_file.endswith(".mp4"):
            parts = video_file.rsplit("_", 2)  # Extract <video_id>_<label>_<frames>
            if len(parts) == 3 and parts[2].replace(".mp4", "").isdigit():
                video_id, label, _ = parts
                video_sources[video_file] = os.path.join(folder, video_file)
                label_counts[label] += 1

# Count videos from both directories
process_videos(shortened_videos_path)
process_videos(raw_videos_path)

target_videos_per_label = 36

# Calculate missing videos per label
total_missing_videos = 0
for label, count in label_counts.items():
    missing_videos = max(0, target_videos_per_label - count)
    total_missing_videos += missing_videos
    print(f"{label}: {count} videos, needs {missing_videos} more")

print(f"🔢 Total videos to be created: {total_missing_videos}")

# Generate augmented videos
for video_file, input_video in video_sources.items():
    parts = video_file.rsplit("_", 2)
    if len(parts) < 3:
        continue
    
    video_id, label, frames = parts
    base_name = os.path.splitext(video_file)[0]
    
    # Calculate how many additional videos are needed
    needed_augmentations = max(0, target_videos_per_label - label_counts[label])
    
    if needed_augmentations == 0:
        print(f"⏩ Skipping {video_file}, already {target_videos_per_label} videos for label {label}")
        continue
    
    applied_augmentations = 0
    for aug_name, filter_cmd in augmentations.items():
        if applied_augmentations >= needed_augmentations:
            break
        
        output_video = os.path.join(augmented_videos_path, f"{base_name}_{aug_name}.mp4")
        
        if os.path.exists(output_video):
            print(f"⏩ {output_video} already exists. Skipping...")
            continue
        
        # Ensure only up to 90 frames are used
        ffmpeg_command = [
            "ffmpeg", "-y",
            "-i", input_video,
        ] + filter_cmd.split() + [
            "-vf", "select='lt(n,90)'",  # Only first 90 frames
            "-vsync", "vfr",
            "-c:v", "libx264", "-preset", "fast", "-crf", "18", "-pix_fmt", "yuv420p", output_video
        ]
        
        print(f"📌 Creating {output_video} with FFmpeg ({aug_name})")
        process = subprocess.run(ffmpeg_command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        
        if process.returncode == 0:
            print(f"✅ Augmented video saved: {output_video}")
            label_counts[label] += 1
            applied_augmentations += 1
        else:
            print(f"❌ Error processing {output_video} with FFmpeg")
            print(process.stderr.decode())

print("✅ Done! Missing augmented videos have been created.")
# Out:
# speech: 8 Videos, benötigt 28 mehr
# basketball: 10 Videos, benötigt 26 mehr
# family: 10 Videos, benötigt 26 mehr
# water: 8 Videos, benötigt 28 mehr
# sweet: 8 Videos, benötigt 28 mehr
# fish: 9 Videos, benötigt 27 mehr
# laugh: 10 Videos, benötigt 26 mehr
# careful: 8 Videos, benötigt 28 mehr
# appointment: 7 Videos, benötigt 29 mehr
# tall: 12 Videos, benötigt 24 mehr
# wow: 8 Videos, benötigt 28 mehr
# cool: 13 Videos, benötigt 23 mehr
# full: 9 Videos, benötigt 27 mehr
# who: 11 Videos, benötigt 25 mehr
# wait: 9 Videos, benötigt 27 mehr
# hearing: 8 Videos, benötigt 28 mehr
# ago: 8 Videos, benötigt 28 mehr
# postpone: 8 Videos, benötigt 28 mehr
# study: 9 Videos, benötigt 27 mehr
# tell: 9 Videos, benötigt 27 mehr
# list: 8 Videos, benötigt 28 mehr
# beard: 8 Videos, benötigt 28 mehr
# government: 8 Videos, benötigt 28 mehr
# woman: 10 Videos, benötigt 26 mehr
# toast: 9 Videos, benötigt 27 mehr
# bowling: 13 Videos, benötigt 23 mehr
# trade: 12 Videos, benötigt 24 mehr
# buy: 8 Videos, benötigt 28 mehr
# give: 9 Videos, benötigt 27 mehr
# glasses: 8 Videos, benötigt 28 mehr
# accident: 12 Videos, benötigt 24 mehr
# silly: 8 Videos, benötigt 28 mehr
# man: 11 Videos, benötigt 25 mehr
# past: 8 Videos, benötigt 28 mehr
# meet: 8 Videos, benötigt 28 mehr
# last: 9 Videos, benötigt 27 mehr
# candy: 11 Videos, benötigt 25 mehr
# president: 8 Videos, benötigt 28 mehr
# same: 8 Videos, benötigt 28 mehr
# cousin: 11 Videos, benötigt 25 mehr
# shirt: 11 Videos, benötigt 25 mehr
# check: 9 Videos, benötigt 27 mehr
# move: 9 Videos, benötigt 27 mehr
# perspective: 8 Videos, benötigt 28 mehr
# hope: 8 Videos, benötigt 28 mehr
# office: 8 Videos, benötigt 28 mehr
# necklace: 8 Videos, benötigt 28 mehr
# computer: 13 Videos, benötigt 23 mehr
# secretary: 9 Videos, benötigt 27 mehr
# short: 11 Videos, benötigt 25 mehr
# environment: 8 Videos, benötigt 28 mehr
# headache: 8 Videos, benötigt 28 mehr
# balance: 9 Videos, benötigt 27 mehr
# school: 8 Videos, benötigt 28 mehr
# work: 9 Videos, benötigt 27 mehr
# chat: 9 Videos, benötigt 27 mehr
# animal: 8 Videos, benötigt 28 mehr
# take: 9 Videos, benötigt 27 mehr
# decorate: 8 Videos, benötigt 28 mehr
# pull: 8 Videos, benötigt 28 mehr
# africa: 8 Videos, benötigt 28 mehr
# stay: 8 Videos, benötigt 28 mehr
# score: 9 Videos, benötigt 27 mehr
# vomit: 8 Videos, benötigt 28 mehr
# brother: 9 Videos, benötigt 27 mehr
# spin: 8 Videos, benötigt 28 mehr
# why: 9 Videos, benötigt 27 mehr
# how: 8 Videos, benötigt 28 mehr
# baby: 8 Videos, benötigt 28 mehr
# carrot: 9 Videos, benötigt 27 mehr
# add: 8 Videos, benötigt 28 mehr
# play: 9 Videos, benötigt 27 mehr
# room: 8 Videos, benötigt 28 mehr
# call: 10 Videos, benötigt 26 mehr
# drink: 12 Videos, benötigt 24 mehr
# drop: 8 Videos, benötigt 28 mehr
# letter: 9 Videos, benötigt 27 mehr
# what: 9 Videos, benötigt 27 mehr
# bed: 12 Videos, benötigt 24 mehr
# wet: 8 Videos, benötigt 28 mehr
# upset: 8 Videos, benötigt 28 mehr
# sandwich: 9 Videos, benötigt 27 mehr
# city: 7 Videos, benötigt 29 mehr
# apple: 10 Videos, benötigt 26 mehr
# change: 11 Videos, benötigt 25 mehr
# thin: 15 Videos, benötigt 21 mehr
# year: 9 Videos, benötigt 27 mehr
# delicious: 9 Videos, benötigt 27 mehr
# later: 10 Videos, benötigt 26 mehr
# follow: 8 Videos, benötigt 28 mehr
# future: 8 Videos, benötigt 28 mehr
# argue: 9 Videos, benötigt 27 mehr
# bird: 9 Videos, benötigt 27 mehr
# bad: 9 Videos, benötigt 27 mehr
# presentation: 8 Videos, benötigt 28 mehr
# banana: 8 Videos, benötigt 28 mehr
# bar: 9 Videos, benötigt 27 mehr
# near: 8 Videos, benötigt 28 mehr
# grammar: 8 Videos, benötigt 28 mehr
# white: 9 Videos, benötigt 27 mehr
# before: 13 Videos, benötigt 23 mehr
# no: 9 Videos, benötigt 27 mehr
# pizza: 11 Videos, benötigt 25 mehr
# barely: 8 Videos, benötigt 28 mehr
# deaf: 10 Videos, benötigt 26 mehr
# ugly: 8 Videos, benötigt 28 mehr
# language: 9 Videos, benötigt 27 mehr
# pink: 8 Videos, benötigt 28 mehr
# delay: 10 Videos, benötigt 26 mehr
# walk: 8 Videos, benötigt 28 mehr
# fat: 9 Videos, benötigt 27 mehr
# alone: 8 Videos, benötigt 28 mehr
# leave: 10 Videos, benötigt 26 mehr
# cow: 8 Videos, benötigt 28 mehr
# inform: 8 Videos, benötigt 28 mehr
# australia: 8 Videos, benötigt 28 mehr
# black: 9 Videos, benötigt 27 mehr
# ready: 9 Videos, benötigt 27 mehr
# great: 8 Videos, benötigt 28 mehr
# dive: 8 Videos, benötigt 28 mehr
# graduate: 9 Videos, benötigt 27 mehr
# dog: 10 Videos, benötigt 26 mehr
# week: 8 Videos, benötigt 28 mehr
# help: 13 Videos, benötigt 23 mehr
# tiger: 8 Videos, benötigt 28 mehr
# orange: 8 Videos, benötigt 28 mehr
# cheat: 9 Videos, benötigt 27 mehr
# decide: 8 Videos, benötigt 28 mehr
# champion: 10 Videos, benötigt 26 mehr
# day: 8 Videos, benötigt 28 mehr
# son: 9 Videos, benötigt 27 mehr
# go: 14 Videos, benötigt 22 mehr
# california: 8 Videos, benötigt 28 mehr
# dark: 11 Videos, benötigt 25 mehr
# hot: 9 Videos, benötigt 27 mehr
# many: 9 Videos, benötigt 27 mehr
# finish: 8 Videos, benötigt 28 mehr
# fast: 8 Videos, benötigt 28 mehr
# cry: 8 Videos, benötigt 28 mehr
# write: 9 Videos, benötigt 27 mehr
# make: 8 Videos, benötigt 28 mehr
# now: 8 Videos, benötigt 28 mehr
# corn: 11 Videos, benötigt 25 mehr
# cold: 11 Videos, benötigt 25 mehr
# show: 8 Videos, benötigt 28 mehr
# visit: 8 Videos, benötigt 28 mehr
# can: 8 Videos, benötigt 28 mehr
# yesterday: 9 Videos, benötigt 27 mehr
# good: 9 Videos, benötigt 27 mehr
# thursday: 10 Videos, benötigt 26 mehr
# daughter: 9 Videos, benötigt 27 mehr
# like: 8 Videos, benötigt 28 mehr
# cat: 8 Videos, benötigt 28 mehr
# party: 8 Videos, benötigt 28 mehr
# convince: 9 Videos, benötigt 27 mehr
# new: 8 Videos, benötigt 28 mehr
# first: 8 Videos, benötigt 28 mehr
# hear: 8 Videos, benötigt 28 mehr
# far: 10 Videos, benötigt 26 mehr
# today: 8 Videos, benötigt 28 mehr
# improve: 8 Videos, benötigt 28 mehr
# girl: 8 Videos, benötigt 28 mehr
# yes: 10 Videos, benötigt 26 mehr
# mother: 9 Videos, benötigt 27 mehr
# interest: 7 Videos, benötigt 29 mehr
# want: 8 Videos, benötigt 28 mehr
# fault: 8 Videos, benötigt 28 mehr
# thanksgiving: 11 Videos, benötigt 25 mehr
# 🔢 Insgesamt zu erstellende Videos: 4537
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53696_speech_88_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53696_speech_88_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53696_speech_88_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53696_speech_88_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53696_speech_88_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53696_speech_88_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53696_speech_88_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53696_speech_88_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53696_speech_88_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53696_speech_88_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53696_speech_88_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53696_speech_88_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05233_basketball_71_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05233_basketball_71_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05233_basketball_71_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05233_basketball_71_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05233_basketball_71_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05233_basketball_71_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05233_basketball_71_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05233_basketball_71_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05233_basketball_71_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05233_basketball_71_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05233_basketball_71_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05233_basketball_71_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/20978_family_62_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/20978_family_62_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/20978_family_62_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/20978_family_62_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/20978_family_62_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/20978_family_62_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/20978_family_62_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/20978_family_62_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/20978_family_62_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/20978_family_62_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/20978_family_62_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/20978_family_62_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62499_water_67_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62499_water_67_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62499_water_67_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62499_water_67_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62499_water_67_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62499_water_67_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62499_water_67_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62499_water_67_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62499_water_67_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62499_water_67_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62499_water_67_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62499_water_67_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56306_sweet_48_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56306_sweet_48_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56306_sweet_48_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56306_sweet_48_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56306_sweet_48_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56306_sweet_48_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56306_sweet_48_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56306_sweet_48_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56306_sweet_48_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56306_sweet_48_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56306_sweet_48_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56306_sweet_48_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/69325_fish_45_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/69325_fish_45_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/69325_fish_45_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/69325_fish_45_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/69325_fish_45_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/69325_fish_45_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/69325_fish_45_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/69325_fish_45_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/69325_fish_45_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/69325_fish_45_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/69325_fish_45_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/69325_fish_45_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32377_laugh_91_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32377_laugh_91_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32377_laugh_91_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32377_laugh_91_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32377_laugh_91_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32377_laugh_91_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32377_laugh_91_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32377_laugh_91_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32377_laugh_91_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32377_laugh_91_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32377_laugh_91_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32377_laugh_91_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09179_careful_78_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09179_careful_78_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09179_careful_78_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09179_careful_78_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09179_careful_78_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09179_careful_78_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09179_careful_78_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09179_careful_78_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09179_careful_78_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09179_careful_78_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09179_careful_78_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09179_careful_78_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/03056_appointment_70_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/03056_appointment_70_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/03056_appointment_70_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/03056_appointment_70_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/03056_appointment_70_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/03056_appointment_70_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/03056_appointment_70_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/03056_appointment_70_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/03056_appointment_70_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/03056_appointment_70_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/03056_appointment_70_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/03056_appointment_70_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56844_tall_41_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56844_tall_41_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56844_tall_41_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56844_tall_41_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56844_tall_41_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56844_tall_41_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56844_tall_41_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56844_tall_41_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56844_tall_41_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56844_tall_41_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56844_tall_41_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56844_tall_41_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_45_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_45_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_45_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_45_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_45_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_45_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_45_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_45_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_45_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_45_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_45_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_45_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/13201_cool_54_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/13201_cool_54_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/13201_cool_54_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/13201_cool_54_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/13201_cool_54_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/13201_cool_54_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/13201_cool_54_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/13201_cool_54_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/13201_cool_54_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/13201_cool_54_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/13201_cool_54_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/13201_cool_54_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23771_full_61_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23771_full_61_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23771_full_61_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23771_full_61_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23771_full_61_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23771_full_61_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23771_full_61_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23771_full_61_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23771_full_61_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23771_full_61_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23771_full_61_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23771_full_61_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63225_who_39_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63225_who_39_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63225_who_39_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63225_who_39_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63225_who_39_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63225_who_39_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63225_who_39_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63225_who_39_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63225_who_39_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63225_who_39_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63225_who_39_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63225_who_39_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62100_wait_57_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62100_wait_57_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62100_wait_57_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62100_wait_57_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62100_wait_57_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62100_wait_57_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62100_wait_57_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62100_wait_57_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62100_wait_57_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62100_wait_57_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62100_wait_57_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62100_wait_57_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/26971_hearing_48_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/26971_hearing_48_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/26971_hearing_48_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/26971_hearing_48_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/26971_hearing_48_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/26971_hearing_48_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/26971_hearing_48_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/26971_hearing_48_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/26971_hearing_48_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/26971_hearing_48_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/26971_hearing_48_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/26971_hearing_48_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/01552_ago_75_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/01552_ago_75_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/01552_ago_75_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/01552_ago_75_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/01552_ago_75_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/01552_ago_75_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/01552_ago_75_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/01552_ago_75_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/01552_ago_75_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/01552_ago_75_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/01552_ago_75_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/01552_ago_75_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/43904_postpone_70_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/43904_postpone_70_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/43904_postpone_70_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/43904_postpone_70_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/43904_postpone_70_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/43904_postpone_70_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/43904_postpone_70_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/43904_postpone_70_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/43904_postpone_70_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/43904_postpone_70_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/43904_postpone_70_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/43904_postpone_70_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/55362_study_64_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/55362_study_64_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/55362_study_64_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/55362_study_64_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/55362_study_64_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/55362_study_64_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/55362_study_64_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/55362_study_64_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/55362_study_64_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/55362_study_64_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/55362_study_64_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/55362_study_64_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/57276_tell_37_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/57276_tell_37_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/57276_tell_37_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/57276_tell_37_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/57276_tell_37_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/57276_tell_37_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/57276_tell_37_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/57276_tell_37_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/57276_tell_37_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/57276_tell_37_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/57276_tell_37_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/57276_tell_37_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/33477_list_88_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/33477_list_88_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/33477_list_88_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/33477_list_88_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/33477_list_88_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/33477_list_88_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/33477_list_88_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/33477_list_88_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/33477_list_88_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/33477_list_88_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/33477_list_88_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/33477_list_88_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05472_beard_75_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05472_beard_75_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05472_beard_75_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05472_beard_75_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05472_beard_75_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05472_beard_75_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05472_beard_75_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05472_beard_75_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05472_beard_75_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05472_beard_75_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05472_beard_75_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05472_beard_75_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/25243_government_63_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/25243_government_63_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/25243_government_63_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/25243_government_63_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/25243_government_63_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/25243_government_63_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/25243_government_63_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/25243_government_63_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/25243_government_63_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/25243_government_63_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/25243_government_63_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/25243_government_63_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63669_woman_58_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63669_woman_58_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63669_woman_58_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63669_woman_58_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63669_woman_58_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63669_woman_58_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63669_woman_58_speedup.mp4 mit FFmpeg (speedup)
# ...
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62506_water_50_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/62506_water_50_speedup.mp4
# ⏩ Überspringe 13329_corn_86.mp4, bereits 36 Videos für Label corn
# ⏩ Überspringe 58450_tiger_68.mp4, bereits 36 Videos für Label tiger
# ⏩ Überspringe 69546_yes_72.mp4, bereits 36 Videos für Label yes
# ⏩ Überspringe 35516_meet_48.mp4, bereits 36 Videos für Label meet
# ⏩ Überspringe 14680_dark_37.mp4, bereits 36 Videos für Label dark
# ⏩ Überspringe 32253_last_31.mp4, bereits 36 Videos für Label last
# ⏩ Überspringe 14757_daughter_44.mp4, bereits 36 Videos für Label daughter
# ⏩ Überspringe 06478_black_45.mp4, bereits 36 Videos für Label black
# ⏩ Überspringe 48514_room_74.mp4, bereits 36 Videos für Label room
# ⏩ Überspringe 12314_computer_43.mp4, bereits 36 Videos für Label computer
# ⏩ Überspringe 32947_letter_30.mp4, bereits 36 Videos für Label letter
# ⏩ Überspringe 16891_dive_29.mp4, bereits 36 Videos für Label dive
