# %%
import os
import subprocess

# Verzeichnisse
input_folder = "/home/haggenmueller/asl_detection/machine_learning/datasets/wlasl/raw_videos"
output_folder = "/home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented"
os.makedirs(output_folder, exist_ok=True)

# 6 Augmentierungen für Gebärdensprache (ohne Rotationen!)
augmentations = {
    "flip": "-vf hflip",  # Horizontale Spiegelung (beidhändige Gebärden bleiben lesbar)
    "bright": "-vf eq=brightness=0.2",  # Helligkeit erhöhen
    "contrast": "-vf eq=contrast=1.5",  # Kontrast verstärken
    "speedup": "-vf setpts=0.75*PTS",  # 25% schneller
    "slowdown": "-vf setpts=1.25*PTS",  # 25% langsamer
    "noise": "-vf noise=c0s=5:allf=t"  # Leichtes Rauschen simulieren
}

# Alle Videos aus dem Roh-Daten-Ordner durchgehen
for video_file in os.listdir(input_folder):
    if not video_file.endswith(".mp4"):
        continue

    input_video = os.path.join(input_folder, video_file)
    base_name = os.path.splitext(video_file)[0]  # Entferne .mp4 aus dem Namen

    for aug_name, filter_cmd in augmentations.items():
        output_video = os.path.join(output_folder, f"{base_name}_{aug_name}.mp4")

        # Falls das augmentierte Video bereits existiert, überspringen
        if os.path.exists(output_video):
            print(f"⏩ {output_video} existiert bereits. Überspringe...")
            continue

        # FFmpeg-Befehl für die Augmentierung
        ffmpeg_command = [
            "ffmpeg",
            "-y",  # Überschreiben erlauben
            "-i", input_video,  # Eingangs-Video
        ] + filter_cmd.split() + [
            "-c:v", "libx264", "-preset", "fast", "-crf", "18", "-pix_fmt", "yuv420p", output_video
        ]

        print(f"📌 Erstelle {output_video} mit FFmpeg ({aug_name})")
        process = subprocess.run(ffmpeg_command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

        if process.returncode == 0:
            print(f"✅ Augmentiertes Video gespeichert: {output_video}")
        else:
            print(f"❌ Fehler beim Speichern von {output_video} mit FFmpeg")
            print(process.stderr.decode())  # Ausgabe der FFmpeg-Fehlermeldung
# Out:
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/19408_environment_121_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/19408_environment_121_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/19408_environment_121_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/19408_environment_121_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/19408_environment_121_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/19408_environment_121_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/19408_environment_121_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/19408_environment_121_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/19408_environment_121_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/19408_environment_121_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/19408_environment_121_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/19408_environment_121_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/28201_how_72_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/28201_how_72_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/28201_how_72_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/28201_how_72_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/28201_how_72_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/28201_how_72_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/28201_how_72_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/28201_how_72_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/28201_how_72_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/28201_how_72_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/28201_how_72_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/28201_how_72_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65798_future_64_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65798_future_64_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65798_future_64_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65798_future_64_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65798_future_64_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65798_future_64_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65798_future_64_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65798_future_64_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65798_future_64_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65798_future_64_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65798_future_64_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65798_future_64_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/08691_call_101_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/08691_call_101_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/08691_call_101_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/08691_call_101_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/08691_call_101_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/08691_call_101_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/08691_call_101_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/08691_call_101_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/08691_call_101_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/08691_call_101_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/08691_call_101_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/08691_call_101_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/66759_week_47_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/66759_week_47_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/66759_week_47_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/66759_week_47_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/66759_week_47_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/66759_week_47_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/66759_week_47_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/66759_week_47_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/66759_week_47_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/66759_week_47_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/66759_week_47_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/66759_week_47_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/45261_pull_131_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/45261_pull_131_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/45261_pull_131_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/45261_pull_131_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/45261_pull_131_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/45261_pull_131_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/45261_pull_131_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/45261_pull_131_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/45261_pull_131_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/45261_pull_131_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/45261_pull_131_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/45261_pull_131_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/17713_drink_91_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/17713_drink_91_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/17713_drink_91_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/17713_drink_91_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/17713_drink_91_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/17713_drink_91_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/17713_drink_91_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/17713_drink_91_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/17713_drink_91_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/17713_drink_91_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/17713_drink_91_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/17713_drink_91_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32257_last_50_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32257_last_50_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32257_last_50_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32257_last_50_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32257_last_50_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32257_last_50_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32257_last_50_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32257_last_50_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32257_last_50_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32257_last_50_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32257_last_50_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/32257_last_50_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/27214_help_53_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/27214_help_53_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/27214_help_53_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/27214_help_53_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/27214_help_53_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/27214_help_53_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/27214_help_53_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/27214_help_53_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/27214_help_53_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/27214_help_53_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/27214_help_53_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/27214_help_53_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49174_same_36_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49174_same_36_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49174_same_36_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49174_same_36_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49174_same_36_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49174_same_36_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49174_same_36_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49174_same_36_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49174_same_36_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49174_same_36_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49174_same_36_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49174_same_36_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_91_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_91_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_91_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_91_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_91_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_91_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_91_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_91_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_91_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_91_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_91_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/63948_wow_91_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56838_tall_96_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56838_tall_96_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56838_tall_96_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56838_tall_96_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56838_tall_96_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56838_tall_96_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56838_tall_96_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56838_tall_96_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56838_tall_96_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56838_tall_96_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56838_tall_96_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/56838_tall_96_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/35509_meet_94_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/35509_meet_94_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/35509_meet_94_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/35509_meet_94_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/35509_meet_94_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/35509_meet_94_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/35509_meet_94_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/35509_meet_94_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/35509_meet_94_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/35509_meet_94_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/35509_meet_94_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/35509_meet_94_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58649_toast_116_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58649_toast_116_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58649_toast_116_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58649_toast_116_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58649_toast_116_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58649_toast_116_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58649_toast_116_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58649_toast_116_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58649_toast_116_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58649_toast_116_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58649_toast_116_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58649_toast_116_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65138_barely_73_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65138_barely_73_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65138_barely_73_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65138_barely_73_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65138_barely_73_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65138_barely_73_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65138_barely_73_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65138_barely_73_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65138_barely_73_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65138_barely_73_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65138_barely_73_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/65138_barely_73_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53707_speech_69_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53707_speech_69_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53707_speech_69_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53707_speech_69_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53707_speech_69_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53707_speech_69_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53707_speech_69_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53707_speech_69_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53707_speech_69_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53707_speech_69_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53707_speech_69_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53707_speech_69_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58444_tiger_64_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58444_tiger_64_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58444_tiger_64_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58444_tiger_64_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58444_tiger_64_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58444_tiger_64_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58444_tiger_64_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58444_tiger_64_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58444_tiger_64_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58444_tiger_64_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58444_tiger_64_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58444_tiger_64_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53873_spin_62_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53873_spin_62_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53873_spin_62_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53873_spin_62_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53873_spin_62_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53873_spin_62_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53873_spin_62_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53873_spin_62_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53873_spin_62_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53873_spin_62_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53873_spin_62_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53873_spin_62_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/04718_bad_40_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/04718_bad_40_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/04718_bad_40_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/04718_bad_40_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/04718_bad_40_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/04718_bad_40_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/04718_bad_40_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/04718_bad_40_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/04718_bad_40_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/04718_bad_40_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/04718_bad_40_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/04718_bad_40_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53878_spin_38_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53878_spin_38_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53878_spin_38_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53878_spin_38_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53878_spin_38_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53878_spin_38_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53878_spin_38_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53878_spin_38_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53878_spin_38_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53878_spin_38_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53878_spin_38_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/53878_spin_38_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/38530_no_53_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/38530_no_53_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/38530_no_53_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/38530_no_53_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/38530_no_53_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/38530_no_53_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/38530_no_53_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/38530_no_53_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/38530_no_53_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/38530_no_53_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/38530_no_53_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/38530_no_53_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10187_check_95_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10187_check_95_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10187_check_95_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10187_check_95_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10187_check_95_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10187_check_95_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10187_check_95_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10187_check_95_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10187_check_95_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10187_check_95_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10187_check_95_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10187_check_95_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/41452_past_31_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/41452_past_31_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/41452_past_31_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/41452_past_31_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/41452_past_31_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/41452_past_31_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/41452_past_31_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/41452_past_31_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/41452_past_31_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/41452_past_31_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/41452_past_31_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/41452_past_31_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23774_full_57_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23774_full_57_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23774_full_57_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23774_full_57_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23774_full_57_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23774_full_57_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23774_full_57_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23774_full_57_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23774_full_57_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23774_full_57_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23774_full_57_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/23774_full_57_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51226_short_77_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51226_short_77_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51226_short_77_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51226_short_77_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51226_short_77_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51226_short_77_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51226_short_77_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51226_short_77_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51226_short_77_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51226_short_77_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51226_short_77_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51226_short_77_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58446_tiger_39_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58446_tiger_39_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58446_tiger_39_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58446_tiger_39_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58446_tiger_39_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58446_tiger_39_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58446_tiger_39_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58446_tiger_39_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58446_tiger_39_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58446_tiger_39_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58446_tiger_39_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/58446_tiger_39_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/40121_orange_42_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/40121_orange_42_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/40121_orange_42_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/40121_orange_42_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/40121_orange_42_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/40121_orange_42_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/40121_orange_42_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/40121_orange_42_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/40121_orange_42_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/40121_orange_42_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/40121_orange_42_noise.mp4 mit FFmpeg (noise)
# ...
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/37093_move_54_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/37093_move_54_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/37093_move_54_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/37093_move_54_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/37093_move_54_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/37093_move_54_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/37093_move_54_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/37093_move_54_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/37093_move_54_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/37093_move_54_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05095_bar_84_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05095_bar_84_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05095_bar_84_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05095_bar_84_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05095_bar_84_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05095_bar_84_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05095_bar_84_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05095_bar_84_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05095_bar_84_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05095_bar_84_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05095_bar_84_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/05095_bar_84_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/15037_decide_48_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/15037_decide_48_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/15037_decide_48_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/15037_decide_48_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/15037_decide_48_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/15037_decide_48_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/15037_decide_48_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/15037_decide_48_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/15037_decide_48_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/15037_decide_48_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/15037_decide_48_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/15037_decide_48_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49697_score_37_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49697_score_37_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49697_score_37_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49697_score_37_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49697_score_37_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49697_score_37_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49697_score_37_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49697_score_37_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49697_score_37_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49697_score_37_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49697_score_37_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/49697_score_37_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09918_champion_28_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09918_champion_28_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09918_champion_28_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09918_champion_28_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09918_champion_28_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09918_champion_28_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09918_champion_28_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09918_champion_28_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09918_champion_28_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09918_champion_28_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09918_champion_28_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/09918_champion_28_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/42243_perspective_123_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/42243_perspective_123_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/42243_perspective_123_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/42243_perspective_123_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/42243_perspective_123_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/42243_perspective_123_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/42243_perspective_123_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/42243_perspective_123_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/42243_perspective_123_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/42243_perspective_123_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/42243_perspective_123_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/42243_perspective_123_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/02106_alone_118_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/02106_alone_118_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/02106_alone_118_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/02106_alone_118_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/02106_alone_118_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/02106_alone_118_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/02106_alone_118_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/02106_alone_118_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/02106_alone_118_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/02106_alone_118_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/02106_alone_118_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/02106_alone_118_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51223_short_33_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51223_short_33_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51223_short_33_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51223_short_33_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51223_short_33_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51223_short_33_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51223_short_33_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51223_short_33_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51223_short_33_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51223_short_33_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51223_short_33_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/51223_short_33_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10151_cheat_33_flip.mp4 mit FFmpeg (flip)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10151_cheat_33_flip.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10151_cheat_33_bright.mp4 mit FFmpeg (bright)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10151_cheat_33_bright.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10151_cheat_33_contrast.mp4 mit FFmpeg (contrast)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10151_cheat_33_contrast.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10151_cheat_33_speedup.mp4 mit FFmpeg (speedup)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10151_cheat_33_speedup.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10151_cheat_33_slowdown.mp4 mit FFmpeg (slowdown)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10151_cheat_33_slowdown.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10151_cheat_33_noise.mp4 mit FFmpeg (noise)
# ✅ Augmentiertes Video gespeichert: /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/10151_cheat_33_noise.mp4
# 📌 Erstelle /home/haggenmueller/asl_detection/machine_learning/datasets/own_dataset/videos_augmented/69291_day_63_flip.mp4 mit FFmpeg (flip)
